# %%
! pip install youtube-transcript-api

# %%
! pip install -r requirements.txt
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
def transcript(id, new_tran):
# importing the module
  from youtube_transcript_api import YouTubeTranscriptApi

# retrieve the available transcripts
  transcript_list = YouTubeTranscriptApi.list_transcripts(id)
  if not transcript_list:
    return
# iterate over all available transcripts
  for transcript in transcript_list:

    # the Transcript object provides metadata
    # properties
      print(
          transcript.video_id,
          transcript.language,
          transcript.language_code,

        # whether it has been manually created or
        # generated by YouTube
          transcript.is_generated,

        # whether this transcript can be translated
        # or not
         transcript.is_translatable,

        # a list of languages the transcript can be
        # translated to
         transcript.translation_languages,
    )

    # fetch the actual transcript data
      print(transcript.fetch())

    # translating the transcript will return another
    # transcript object
      print(transcript.translate('en').fetch())

# you can also directly filter for the language you are
# looking for, using the transcript list
      if(new_tran == "high_036"):
         transcript = transcript_list.find_transcript(['nl'])
      else:
        transcript = transcript_list.find_transcript(['en'])

# or just filter for manually created transcripts
#transcript = transcript_list.find_manually_created_transcript(['en'])
      #transcript = transcript_list.find_generated_transcript(['en'])
# importing modules
  from youtube_transcript_api import YouTubeTranscriptApi

# using the srt variable with the list of dictionaries
# obtained by the .get_transcript() function
  srt = YouTubeTranscriptApi.get_transcript(id)

# creating or overwriting a file "subtitles.txt" with
# the info inside the context manager
  with open("/content/transcripts/"+new_tran+".txt", "w") as f:

        # iterating through each element of list srt
    for i in srt:
        # writing each element of srt on a new line
        f.write("{}\n".format(i))

# %%
def transcript2(id, new_tran):
# importing the module
  from youtube_transcript_api import YouTubeTranscriptApi

# retrieve the available transcripts
  transcript_list = YouTubeTranscriptApi.list_transcripts(id)
  if not transcript_list:
    return
# iterate over all available transcripts
  for transcript in transcript_list:

    # the Transcript object provides metadata
    # properties
      print(
          transcript.video_id,
          transcript.language,
          transcript.language_code,

        # whether it has been manually created or
        # generated by YouTube
          transcript.is_generated,

        # whether this transcript can be translated
        # or not
         transcript.is_translatable,

        # a list of languages the transcript can be
        # translated to
         transcript.translation_languages,
    )

    # fetch the actual transcript data
      print(transcript.fetch())

    # translating the transcript will return another
    # transcript object
      print(transcript.translate('en').fetch())

# you can also directly filter for the language you are
# looking for, using the transcript list
      if(new_tran == "high_036"):
         transcript = transcript_list.find_transcript(['nl'])
      else:
        transcript = transcript_list.find_transcript(['en'])

# or just filter for manually created transcripts
#transcript = transcript_list.find_manually_created_transcript(['en'])
      #transcript = transcript_list.find_generated_transcript(['en'])
# importing modules
  from youtube_transcript_api import YouTubeTranscriptApi

# using the srt variable with the list of dictionaries
# obtained by the .get_transcript() function
  srt = YouTubeTranscriptApi.get_transcript(id)

# creating or overwriting a file "subtitles.txt" with
# the info inside the context manager


        # iterating through each element of list srt
  time = 0
  for i in srt:
        time = time + i["duration"]
  avg_time = time / len(srt)
  return  avg_time

# %%
import csv
#check 134 for the dutch translation
with open('/content/urls.csv', newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    count = 0
    time_avg = [0] * 209
    id = [0] * 209
    for row in reader:
      if( row["id"] == 'high_003' or row["id"] == 'high_018' or row["url"] == 'NA'
         or row["id"] == 'high_036' or row["id"] == 'high_044'
         or row["id"] == 'high_045' or row["id"] == 'high_094' or row["id"] == 'high_097'
         or row["id"] == 'high_104' or row["id"] == 'high_108' or row["id"] == 'high_110'
         or row["id"] == 'high_115' or row["id"] == 'high_117' or row["id"] == 'high_118'
         or row["id"] == 'high_119' or row["id"] == 'high_125'
         or row["id"] == 'high_127' or row["id"] == 'high_128' or row["id"] == 'high_131'
         or row["id"] == 'high_135' or row["id"] == 'high_138' or row["id"] == 'low_005'
         or row["id"] == 'low_010'  or row["id"] == 'low_012'  or row["id"] == 'low_036'
         or row["id"] == 'low_038'  or row["id"] == 'low_039'  or row["id"] == 'low_051'
         or row["id"] == 'low_052' or row["id"] == 'low_068' or row["id"] == 'low_087'
         or row["id"] == 'low_089' ):


        continue
      elif "=" in row["url"]:
        x = row["url"].split("=")
        id[count] =row["id"]
        time_avg[count] = transcript2(x[1], row["id"])
        count = count + 1
      else:
         x = row["url"].split("/")
         id[count] =row["id"]
         print("\nData:" + x[1])
         time_avg[count] = transcript2(x[3], row["id"])
         count = count + 1


         #transcript(x[3], row["id"])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
x = "https://youtu.be/QOxVab_a3ZI".split("/")
print(x[3])
# Out:
# QOxVab_a3ZI

# %%
with open('testtime.csv', 'w', newline='') as csvfile:
    fieldnames = ['id', 'time_avg']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    count = 0
    writer.writeheader()
    for at in range(len(id)):
      writer.writerow({'id': id[count], 'time_avg': time_avg[count] })
      count = count + 1

# %%
import shutil
shutil.make_archive('transcripts', 'zip', '/content/transcripts')
# Out:
# '/content/transcripts.zip'

# %%
import re
avg = 1
test = "C: qiejqow oiajd awd sd qwe ijqwe r [Duration:53]"
dur = test.split("[")
print(dur)
res = re.findall(r'\:.*?\]', test)
temp = res[0]
temp =temp.replace(':', '')
temp = temp.replace(']', '')
temp = temp.replace(' ', '')

avg+= int(temp)
print( avg)
# Out:
# ['C: qiejqow oiajd awd sd qwe ijqwe r ', 'Duration:53]']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-e915412aadac> in <cell line: 12>()
#      10 temp = temp.replace(' ', '')
#      11
# ---> 12 avg+= int(temp)
#      13 print( avg)
#
# ValueError: invalid literal for int() with base 10: 'qiejqowoiajdawdsdqweijqwer[Duration53'
